# %%
import numpy as np
import math

# %%
from main_test import *

# %%
Taylor_Green_test(elbmhwm, n=64)
Taylor_Green_test(elbmhwm, n=128)
Taylor_Green_test(elbmc, n=64)

# %%
Taylor_Green_test(lbmhwm, n=64)
Taylor_Green_test(lbmhwm, n=128)
Taylor_Green_test(lbmc, n=64)

# %%
Taylor_Green_test(mixhwm, n=64)
Taylor_Green_test(mixhwm, n=128)
Taylor_Green_test(elbmc, n=64)
