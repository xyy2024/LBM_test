# %%
from newd2q9 import D2Q9Space_SingleNode_IrregularDomain, D2Q9Space
from main_test import Taylor_Green_ranktest_Irregular_Domain, Taylor_Green_init_Irregular_Domain
from main_test1 import Taylor_Green_ranktest, Taylor_Green_init
#import numpy as np

#Taylor_Green_ranktest(D2Q9Space)
Taylor_Green_ranktest_Irregular_Domain(D2Q9Space_SingleNode_IrregularDomain)
#solver = Taylor_Green_init_Irregular_Domain(D2Q9Space_SingleNode_IrregularDomain, dx=1/2)
#solver.show_flow()
# Out:
# Rank: 0.8535391969215835
# np.float64(0.8535391969215835)
